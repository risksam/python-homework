# %% [markdown]
# # LSTM Stock Predictor Using Closing Prices
#
# In this notebook, you will build and train a custom LSTM RNN that uses a 10 day window of Bitcoin closing prices to predict the 11th day closing price.
#
# You will need to:
#
# 1. Prepare the data for training and testing
# 2. Build and train a custom LSTM RNN
# 3. Evaluate the performance of the model

# %% [markdown]
# ## Data Preparation
#
# In this section, you will need to prepare the training and testing data for the model. The model will use a rolling 10 day window to predict the 11th day closing price.
#
# You will need to:
# 1. Use the `window_data` function to generate the X and y values for the model.
# 2. Split the data into 70% training and 30% testing
# 3. Apply the MinMaxScaler to the X and y values
# 4. Reshape the X_train and X_test data for the model. Note: The required input format for the LSTM is:
#
# ```python
# reshape((X_train.shape[0], X_train.shape[1], 1))
# ```

# %%
import numpy as np
import pandas as pd
import hvplot.pandas

# %%
# Set the random seed for reproducibility
# Note: This is for the homework solution, but it is good practice to comment this out and run multiple experiments to evaluate your model
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)

# %%
# Load the fear and greed sentiment data for Bitcoin
df = pd.read_csv('btc_sentiment.csv', index_col="date", infer_datetime_format=True, parse_dates=True)
df = df.drop(columns="fng_classification")
df.head()
# Out:
#              fng_value
# date
# 2019-07-29          19
# 2019-07-28          16
# 2019-07-27          47
# 2019-07-26          24
# 2019-07-25          42

# %%
# Load the historical closing prices for Bitcoin
df2 = pd.read_csv('btc_historic.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)['Close']
df2 = df2.sort_index()
df2.tail()
# Out:
# Date
# 2019-07-25    9882.429688
# 2019-07-26    9847.450195
# 2019-07-27    9478.320313
# 2019-07-28    9531.769531
# 2019-07-29    9529.889648
# Name: Close, dtype: float64

# %%
# Join the data into a single DataFrame
df = df.join(df2, how="inner")
df.tail()
# Out:
#              fng_value        Close
# 2019-07-25          42  9882.429688
# 2019-07-26          24  9847.450195
# 2019-07-27          47  9478.320313
# 2019-07-28          16  9531.769531
# 2019-07-29          19  9529.889648

# %%
df.head()
# Out:
#              fng_value        Close
# 2018-02-01          30  9114.719727
# 2018-02-02          15  8870.820313
# 2018-02-03          40  9251.269531
# 2018-02-04          24  8218.049805
# 2018-02-05          11  6937.080078

# %%
# This function accepts the column number for the features (X) and the target (y)
# It chunks the data up with a rolling window of Xt-n to predict Xt
# It returns a numpy array of X any y
def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of previous closing prices
# Then, experiment with window sizes anywhere from 1 to 10 and see how the model performance changes
window_size = 10

# Column index 0 is the 'fng_value' column
# Column index 1 is the `Close` column
feature_column = 1
target_column = 1
X, y = window_data(df, window_size, feature_column, target_column)

# %%
# Use 70% of the data for training and the remaineder for testing
# YOUR CODE HERE!
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
def split(X, y):
    split = int(0.7 * len(X))
    X_train = X[: split]
    X_test = X[split:]
    y_train = y[: split]
    y_test = y[split:]
    return(X_train, X_test, y_train, y_test)

# %%
from sklearn.preprocessing import MinMaxScaler
# Use the MinMaxScaler to scale data between 0 and 1.
# YOUR CODE HERE!
x_train_scaler = MinMaxScaler()
x_test_scaler = MinMaxScaler()
y_train_scaler = MinMaxScaler()
y_test_scaler = MinMaxScaler()


#fit da scalers to training data
x_train_scaler.fit(X_train)
y_train_scaler.fit(y_train)

#fit da training scaler
X_train = x_train_scaler.transform(X_train)
y_train = y_train_scaler.transform(y_train)

#fit da scalers to test data
x_test_scaler.fit(X_test)
y_test_scaler.fit(y_test)

#fit da test scalers
X_test = x_test_scaler.transform(X_test)
y_test = y_test_scaler.transform(y_test)

# %%
# Reshape the features for the model
# YOUR CODE HERE!
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.7111066 ]
#   [0.68162134]
#   [0.72761425]
#   [0.60270722]
#   [0.44784942]
#   [0.54023074]
#   [0.52711046]
#   [0.60786209]
#   [0.66058747]
#   [0.64516902]]
#
#  [[0.68162134]
#   [0.72761425]
#   [0.60270722]
#   [0.44784942]
#   [0.54023074]
#   [0.52711046]
#   [0.60786209]
#   [0.66058747]
#   [0.64516902]
#   [0.58657552]]
#
#  [[0.72761425]
#   [0.60270722]
#   [0.44784942]
#   [0.54023074]
#   [0.52711046]
#   [0.60786209]
#   [0.66058747]
#   [0.64516902]
#   [0.58657552]
#   [0.68651129]]
#
#  [[0.60270722]
#   [0.44784942]
#   [0.54023074]
#   [0.52711046]
#   [0.60786209]
#   [0.66058747]
#   [0.64516902]
#   [0.58657552]
#   [0.68651129]
#   [0.64219515]]
#
#  [[0.44784942]
#   [0.54023074]
#   [0.52711046]
#   [0.60786209]
#   [0.66058747]
#   [0.64516902]
#   [0.58657552]
#   [0.68651129]
#   [0.64219515]
#   [0.7559475 ]]]
#
# X_test sample values:
# [[[0.01034043]
#   [0.00242586]
#   [0.00307681]
#   [0.00183924]
#   [0.        ]
#   [0.        ]
#   [0.        ]
#   [0.        ]
#   [0.        ]
#   [0.01974407]]
#
#  [[0.00242586]
#   [0.00307681]
#   [0.00183924]
#   [0.        ]
#   [0.00051155]
#   [0.00254834]
#   [0.00577449]
#   [0.        ]
#   [0.02614593]
#   [0.02101502]]
#
#  [[0.00307681]
#   [0.00183924]
#   [0.        ]
#   [0.00051155]
#   [0.00305859]
#   [0.00830812]
#   [0.00577449]
#   [0.02614593]
#   [0.02740859]
#   [0.02643977]]
#
#  [[0.00183924]
#   [0.        ]
#   [0.00051155]
#   [0.00305859]
#   [0.00881542]
#   [0.00830812]
#   [0.03176945]
#   [0.02740859]
#   [0.03279791]
#   [0.02240906]]
#
#  [[0.        ]
#   [0.00051155]
#   [0.00305859]
#   [0.00881542]
#   [0.00881542]
#   [0.03423683]
#   [0.03302481]
#   [0.03279791]
#   [0.02879352]
#   [0.02747223]]]

# %% [markdown]
# ---

# %% [markdown]
# ## Build and Train the LSTM RNN
#
# In this section, you will design a custom LSTM RNN and fit (train) it using the training data.
#
# You will need to:
# 1. Define the model architecture
# 2. Compile the model
# 3. Fit the model to the training data
#
# ### Hints:
# You will want to use the same model architecture and random seed for both notebooks. This is necessary to accurately compare the performance of the FNG model vs the closing price model.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Build the LSTM model. 
# The return sequences need to be set to True if you are adding additional LSTM layers, but 
# You don't have to do this for the final layer. 
# Note: The dropouts help prevent overfitting
# Note: The input shape is the number of time steps and the number of indicators
# Note: Batching inputs has a different input shape of Samples/TimeSteps/Features

# YOUR CODE HERE!
model = Sequential()

number_units = 30
dropout_fraction = 0.1


# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
# YOUR CODE HERE!
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
# YOUR CODE HERE!
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 30)            3840
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 30)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 30)            7320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 30)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30)                7320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
# Use at least 10 epochs
# Do not shuffle the data
# Experiement with the batch size, but a smaller batch size is recommended
# YOUR CODE HERE!
model.fit(X_train, y_train, epochs=20, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/20
# 372/372 [==============================] - 5s 5ms/step - loss: 0.0761
# Epoch 2/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0656
# Epoch 3/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0833
# Epoch 4/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0771
# Epoch 5/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0659
# Epoch 6/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0618
# Epoch 7/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0562
# Epoch 8/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0497
# Epoch 9/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0512
# Epoch 10/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0493
# Epoch 11/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0440
# Epoch 12/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0423
# Epoch 13/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0386
# Epoch 14/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0371
# Epoch 15/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0321
# Epoch 16/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0284
# Epoch 17/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0274
# Epoch 18/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0234
# Epoch 19/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0190
# Epoch 20/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0173

# %% [markdown]
# ---

# %% [markdown]
# ## Model Performance
#
# In this section, you will evaluate the model using the test data.
#
# You will need to:
# 1. Evaluate the model using the `X_test` and `y_test` data.
# 2. Use the X_test data to make predictions
# 3. Create a DataFrame of Real (y_test) vs predicted values.
# 4. Plot the Real vs predicted values as a line chart
#
# ### Hints
# Remember to apply the `inverse_transform` function to the predicted and y_test values to recover the actual closing prices.

# %%
# Evaluate the model
# YOUR CODE HERE!
model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 1s 3ms/step - loss: 0.0167
# 0.016652226448059082

# %%
# Make some predictions
# YOUR CODE HERE!
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = y_test_scaler.inverse_transform(predicted)
real_prices = y_test_scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
}, index = df.index[-len(real_prices): ]) 
stocks.head()
# Out:
#                    Real    Predicted
# 2019-02-20  3924.239990  4019.141846
# 2019-02-21  3974.050049  4102.458008
# 2019-02-22  3937.040039  4156.774414
# 2019-02-23  3983.530029  4160.077637
# 2019-02-24  4149.089844  4150.795898

# %%
# Plot the real vs predicted values as a line chart
# YOUR CODE HERE!
stocks.plot()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/samuelwytenburg/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
evaluations = []
for n in range(1,11):
    X, y = window_data(df, n, feature_column, target_column)
    X_train, X_test, y_train, y_test = split(X, y)
    x_train_scaler = MinMaxScaler()
    x_test_scaler = MinMaxScaler()
    y_train_scaler = MinMaxScaler()
    y_test_scaler = MinMaxScaler()


    #fit da scalers to training data
    x_train_scaler.fit(X_train)
    y_train_scaler.fit(y_train)

    #fit da training scaler
    X_train = x_train_scaler.transform(X_train)
    y_train = y_train_scaler.transform(y_train)

    #fit da scalers to test data
    x_test_scaler.fit(X_test)
    y_test_scaler.fit(y_test)

    #fit da test scalers
    X_test = x_test_scaler.transform(X_test)
    y_test = y_test_scaler.transform(y_test)
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
    model = Sequential()

    number_units = 30
    dropout_fraction = 0.1


    # Layer 1
    model.add(LSTM(
        units=number_units,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1))
        )
    model.add(Dropout(dropout_fraction))
    # Layer 2
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    # Layer 3
    model.add(LSTM(units=number_units))
    model.add(Dropout(dropout_fraction))
    # Output layer
    model.add(Dense(1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    model.summary()
    model.fit(X_train, y_train, epochs=20, shuffle=False, batch_size=1, verbose=1)
    
    evaluations.append(model.evaluate(X_test, y_test))
    predicted = model.predict(X_test)
    predicted_prices = y_test_scaler.inverse_transform(predicted)
    real_prices = y_test_scaler.inverse_transform(y_test.reshape(-1, 1))
    stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = df.index[-len(real_prices): ]) 
    stocks.head()
    stocks.plot()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 1, 30)             3840
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 30)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 30)             7320
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 30)             0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 30)                7320
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 378/378 [==============================] - 4s 2ms/step - loss: 0.1873
# Epoch 2/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0743
# Epoch 3/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0561
# Epoch 4/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0354
# Epoch 5/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0221
# Epoch 6/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0162
# Epoch 7/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0090
# Epoch 8/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0089
# Epoch 9/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0082
# Epoch 10/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0102
# Epoch 11/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0097
# Epoch 12/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0127
# Epoch 13/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 14/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0115
# Epoch 15/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0110
# Epoch 16/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0109
# Epoch 17/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0119
# Epoch 18/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 19/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 20/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0116
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0174
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 2, 30)             3840
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 30)             0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 2, 30)             7320
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 30)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 30)                7320
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 378/378 [==============================] - 4s 3ms/step - loss: 0.1501
# Epoch 2/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0614
# Epoch 3/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0512
# Epoch 4/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0377
# Epoch 5/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0275
# Epoch 6/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0219
# Epoch 7/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0197
# Epoch 8/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0194
# Epoch 9/20
# 378/378 [==============================] - 1s 3ms/step - loss: 0.0179
# Epoch 10/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0202
# Epoch 11/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0183
# Epoch 12/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0197
# Epoch 13/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0168
# Epoch 14/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0176
# Epoch 15/20
# 378/378 [==============================] - 1s 3ms/step - loss: 0.0159
# Epoch 16/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0149
# Epoch 17/20
# 378/378 [==============================] - 1s 3ms/step - loss: 0.0162
# Epoch 18/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0137
# Epoch 19/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0126
# Epoch 20/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0145
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0196
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 3, 30)             3840
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 3, 30)             0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 3, 30)             7320
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 3, 30)             0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 377/377 [==============================] - 4s 3ms/step - loss: 0.1072
# Epoch 2/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0478
# Epoch 3/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0459
# Epoch 4/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0436
# Epoch 5/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0365
# Epoch 6/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0323
# Epoch 7/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0258
# Epoch 8/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0212
# Epoch 9/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0256
# Epoch 10/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0228
# Epoch 11/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0221
# Epoch 12/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0207
# Epoch 13/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0196
# Epoch 14/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0195
# Epoch 15/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0188
# Epoch 16/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0172
# Epoch 17/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0172
# Epoch 18/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0161
# Epoch 19/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0156
# Epoch 20/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0147
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0159
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 4, 30)             3840
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 30)             0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 4, 30)             7320
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 4, 30)             0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 376/376 [==============================] - 5s 3ms/step - loss: 0.0927
# Epoch 2/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0492
# Epoch 3/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0550
# Epoch 4/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0566
# Epoch 5/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0464
# Epoch 6/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0362
# Epoch 7/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0326
# Epoch 8/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0292
# Epoch 9/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0293
# Epoch 10/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0259
# Epoch 11/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0248
# Epoch 12/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0242
# Epoch 13/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0228
# Epoch 14/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0242
# Epoch 15/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0221
# Epoch 16/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0202
# Epoch 17/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0191
# Epoch 18/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0183
# Epoch 19/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0186
# Epoch 20/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0182
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0206
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 5, 30)             3840
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 5, 30)             0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 5, 30)             7320
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 5, 30)             0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 4s 4ms/step - loss: 0.0913
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0491
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0602
# Epoch 4/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0651
# Epoch 5/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0573
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0455
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0342
# Epoch 8/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0324
# Epoch 9/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0316
# Epoch 10/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0297
# Epoch 11/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0295
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0271
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0262
# Epoch 14/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0238
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0235
# Epoch 16/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0235
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0213
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0200
# Epoch 19/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0198
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0171
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0214
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 6, 30)             3840
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 6, 30)             0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 6, 30)             7320
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 6, 30)             0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 4s 4ms/step - loss: 0.0952
# Epoch 2/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0515
# Epoch 3/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0607
# Epoch 4/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0668
# Epoch 5/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0627
# Epoch 6/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0510
# Epoch 7/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0428
# Epoch 8/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0381
# Epoch 9/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0383
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0325
# Epoch 11/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0334
# Epoch 12/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0308
# Epoch 13/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0303
# Epoch 14/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0258
# Epoch 15/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0262
# Epoch 16/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0276
# Epoch 17/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0237
# Epoch 18/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0208
# Epoch 19/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0208
# Epoch 20/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0193A: 0s
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0221
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_21 (LSTM)               (None, 7, 30)             3840
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 7, 30)             0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 7, 30)             7320
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 7, 30)             0
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 374/374 [==============================] - 5s 4ms/step - loss: 0.0851
# Epoch 2/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0550
# Epoch 3/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0737
# Epoch 4/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0820
# Epoch 5/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0668
# Epoch 6/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0537
# Epoch 7/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0456
# Epoch 8/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0421
# Epoch 9/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0388
# Epoch 10/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0364
# Epoch 11/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0382
# Epoch 12/20
# 374/374 [==============================] - 2s 5ms/step - loss: 0.0343
# Epoch 13/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0313
# Epoch 14/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0301
# Epoch 15/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0305
# Epoch 16/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0256
# Epoch 17/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0250
# Epoch 18/20
# 374/374 [==============================] - 2s 5ms/step - loss: 0.0225
# Epoch 19/20
# 374/374 [==============================] - 2s 5ms/step - loss: 0.0206
# Epoch 20/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0199
# 6/6 [==============================] - 1s 3ms/step - loss: 0.0191
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 8, 30)             3840
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 8, 30)             0
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 8, 30)             7320
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8, 30)             0
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 373/373 [==============================] - 5s 5ms/step - loss: 0.0938
# Epoch 2/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0604
# Epoch 3/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0749
# Epoch 4/20
# 373/373 [==============================] - 2s 4ms/step - loss: 0.0805
# Epoch 5/20
# 373/373 [==============================] - 2s 4ms/step - loss: 0.0691
# Epoch 6/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0587
# Epoch 7/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0470
# Epoch 8/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0449
# Epoch 9/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0406
# Epoch 10/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0434
# Epoch 11/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0418
# Epoch 12/20
# 373/373 [==============================] - 2s 4ms/step - loss: 0.0402
# Epoch 13/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0310
# Epoch 14/20
# 373/373 [==============================] - 2s 4ms/step - loss: 0.0311
# Epoch 15/20
# 373/373 [==============================] - 2s 4ms/step - loss: 0.0280
# Epoch 16/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0274
# Epoch 17/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0274
# Epoch 18/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0233
# Epoch 19/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0226
# Epoch 20/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0200
# 6/6 [==============================] - 1s 3ms/step - loss: 0.0178
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_27 (LSTM)               (None, 9, 30)             3840
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 9, 30)             0
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 9, 30)             7320
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 9, 30)             0
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 373/373 [==============================] - 5s 5ms/step - loss: 0.0634
# Epoch 2/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0589
# Epoch 3/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0731
# Epoch 4/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0809
# Epoch 5/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0696
# Epoch 6/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0631
# Epoch 7/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0535
# Epoch 8/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0481
# Epoch 9/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0414
# Epoch 10/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0440
# Epoch 11/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0400
# Epoch 12/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0370
# Epoch 13/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0330
# Epoch 14/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0272
# Epoch 15/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0239
# Epoch 16/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0214
# Epoch 17/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0204
# Epoch 18/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0146
# Epoch 19/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0158
# Epoch 20/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0127
# 5/5 [==============================] - 1s 3ms/step - loss: 0.0136
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_30 (LSTM)               (None, 10, 30)            3840
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 10, 30)            0
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 10, 30)            7320
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 10, 30)            0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 372/372 [==============================] - 5s 5ms/step - loss: 0.0769
# Epoch 2/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0693
# Epoch 3/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0874
# Epoch 4/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0888
# Epoch 5/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0756
# Epoch 6/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0649
# Epoch 7/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0571
# Epoch 8/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0514
# Epoch 9/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0503
# Epoch 10/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0483
# Epoch 11/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0426
# Epoch 12/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0378
# Epoch 13/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0393
# Epoch 14/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0345
# Epoch 15/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0296
# Epoch 16/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0277
# Epoch 17/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0230
# Epoch 18/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0198
# Epoch 19/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0177
# Epoch 20/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0145
# 5/5 [==============================] - 1s 4ms/step - loss: 0.0164

# %% [markdown]
# evaluations

# %%
evaluations
# Out:
# [0.017351200804114342,
#  0.019572408869862556,
#  0.01594170182943344,
#  0.0205643642693758,
#  0.02137177437543869,
#  0.022096779197454453,
#  0.019095072522759438,
#  0.017808329313993454,
#  0.013551187701523304,
#  0.0163736492395401]
