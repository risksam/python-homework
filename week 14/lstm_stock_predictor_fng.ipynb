# %% [markdown]
# # LSTM Stock Predictor Using Fear and Greed Index
#
# In this notebook, you will build and train a custom LSTM RNN that uses a 10 day window of Bitcoin fear and greed index values to predict the 11th day closing price.
#
# You will need to:
#
# 1. Prepare the data for training and testing
# 2. Build and train a custom LSTM RNN
# 3. Evaluate the performance of the model

# %% [markdown]
# ## Data Preparation
#
# In this section, you will need to prepare the training and testing data for the model. The model will use a rolling 10 day window to predict the 11th day closing price.
#
# You will need to:
# 1. Use the `window_data` function to generate the X and y values for the model.
# 2. Split the data into 70% training and 30% testing
# 3. Apply the MinMaxScaler to the X and y values
# 4. Reshape the X_train and X_test data for the model. Note: The required input format for the LSTM is:
#
# ```python
# reshape((X_train.shape[0], X_train.shape[1], 1))
# ```

# %%
import numpy as np
import pandas as pd
import hvplot.pandas

# %%
# Set the random seed for reproducibility
# Note: This is for the homework solution, but it is good practice to comment this out and run multiple experiments to evaluate your model
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)

# %%
# Load the fear and greed sentiment data for Bitcoin
df = pd.read_csv('btc_sentiment.csv', index_col="date", infer_datetime_format=True, parse_dates=True)
df = df.drop(columns="fng_classification")
df.head()
# Out:
#              fng_value
# date
# 2019-07-29          19
# 2019-07-28          16
# 2019-07-27          47
# 2019-07-26          24
# 2019-07-25          42

# %%
# Load the historical closing prices for Bitcoin
df2 = pd.read_csv('btc_historic.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)['Close']
df2 = df2.sort_index()
df2.tail()
# Out:
# Date
# 2019-07-25    9882.429688
# 2019-07-26    9847.450195
# 2019-07-27    9478.320313
# 2019-07-28    9531.769531
# 2019-07-29    9529.889648
# Name: Close, dtype: float64

# %%
# Join the data into a single DataFrame
df = df.join(df2, how="inner")
df.tail()
# Out:
#              fng_value        Close
# 2019-07-25          42  9882.429688
# 2019-07-26          24  9847.450195
# 2019-07-27          47  9478.320313
# 2019-07-28          16  9531.769531
# 2019-07-29          19  9529.889648

# %%
df.head()
# Out:
#              fng_value        Close
# 2018-02-01          30  9114.719727
# 2018-02-02          15  8870.820313
# 2018-02-03          40  9251.269531
# 2018-02-04          24  8218.049805
# 2018-02-05          11  6937.080078

# %%
# This function accepts the column number for the features (X) and the target (y)
# It chunks the data up with a rolling window of Xt-n to predict Xt
# It returns a numpy array of X any y
def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of previous fng values
# Then, experiment with window sizes anywhere from 1 to 10 and see how the model performance changes
window_size = 1

# Column index 0 is the 'fng_value' column
# Column index 1 is the `Close` column
feature_column = 0
target_column = 1
X, y = window_data(df, window_size, feature_column, target_column)

# %%
# Use 70% of the data for training and the remaineder for testing
# YOUR CODE HERE!
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
from sklearn.preprocessing import MinMaxScaler
# Use the MinMaxScaler to scale data between 0 and 1.
# YOUR CODE HERE!
x_train_scaler = MinMaxScaler()
x_test_scaler = MinMaxScaler()
y_train_scaler = MinMaxScaler()
y_test_scaler = MinMaxScaler()


#fit da scalers to training data
x_train_scaler.fit(X_train)
y_train_scaler.fit(y_train)

#fit da training scaler
X_train = x_train_scaler.transform(X_train)
y_train = y_train_scaler.transform(y_train)

#fit da scalers to test data
x_test_scaler.fit(X_test)
y_test_scaler.fit(y_test)

#fit da test scalers
X_test = x_test_scaler.transform(X_test)
y_test = y_test_scaler.transform(y_test)

# %%
# Reshape the features for the model
# YOUR CODE HERE!
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.33333333]]
#
#  [[0.10606061]]
#
#  [[0.48484848]]
#
#  [[0.24242424]]
#
#  [[0.04545455]]]
#
# X_test sample values:
# [[[0.34177215]]
#
#  [[0.3164557 ]]
#
#  [[0.27848101]]
#
#  [[0.59493671]]
#
#  [[0.62025316]]]

# %% [markdown]
# ---

# %% [markdown]
# ## Build and Train the LSTM RNN
#
# In this section, you will design a custom LSTM RNN and fit (train) it using the training data.
#
# You will need to:
# 1. Define the model architecture
# 2. Compile the model
# 3. Fit the model to the training data
#
# ### Hints:
# You will want to use the same model architecture and random seed for both notebooks. This is necessary to accurately compare the performance of the FNG model vs the closing price model.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Build the LSTM model. 
# The return sequences need to be set to True if you are adding additional LSTM layers, but 
# You don't have to do this for the final layer. 
# Note: The dropouts help prevent overfitting
# Note: The input shape is the number of time steps and the number of indicators
# Note: Batching inputs has a different input shape of Samples/TimeSteps/Features

# YOUR CODE HERE!
model = Sequential()

number_units = 30
dropout_fraction = 0.1


# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
# YOUR CODE HERE!
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
# YOUR CODE HERE!
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_30 (LSTM)               (None, 1, 30)             3840
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 1, 30)             0
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 1, 30)             7320
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 1, 30)             0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
# Use at least 10 epochs
# Do not shuffle the data
# Experiement with the batch size, but a smaller batch size is recommended
# YOUR CODE HERE!
model.fit(X_train, y_train, epochs=20, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/20
# 378/378 [==============================] - 4s 2ms/step - loss: 0.1903
# Epoch 2/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1080
# Epoch 3/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1059
# Epoch 4/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0995
# Epoch 5/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0974
# Epoch 6/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0968
# Epoch 7/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0955
# Epoch 8/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0952
# Epoch 9/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0975
# Epoch 10/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0970
# Epoch 11/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0986
# Epoch 12/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1010
# Epoch 13/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1027
# Epoch 14/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1017
# Epoch 15/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1004
# Epoch 16/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1014
# Epoch 17/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0992
# Epoch 18/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1001
# Epoch 19/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1017
# Epoch 20/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1004

# %% [markdown]
# ---

# %% [markdown]
# ## Model Performance
#
# In this section, you will evaluate the model using the test data.
#
# You will need to:
# 1. Evaluate the model using the `X_test` and `y_test` data.
# 2. Use the X_test data to make predictions
# 3. Create a DataFrame of Real (y_test) vs predicted values.
# 4. Plot the Real vs predicted values as a line chart
#
# ### Hints
# Remember to apply the `inverse_transform` function to the predicted and y_test values to recover the actual closing prices.

# %%
# Evaluate the model
# YOUR CODE HERE!
model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1007
# 0.1007157564163208

# %%
# Make some predictions
# YOUR CODE HERE!

# %%
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = y_test_scaler.inverse_transform(predicted)
real_prices = y_test_scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
}, index = df.index[-len(real_prices): ]) 
stocks.head()
# Out:
#                    Real    Predicted
# 2019-02-17  3670.919922  5069.149902
# 2019-02-18  3670.919922  4975.484863
# 2019-02-19  3912.570068  4837.417969
# 2019-02-20  3924.239990  5955.277832
# 2019-02-21  3974.050049  6026.850098

# %%
# Plot the real vs predicted values as a line chart
# YOUR CODE HERE!
stocks.plot()

# %%
def split(X, y):
    split = int(0.7 * len(X))
    X_train = X[: split]
    X_test = X[split:]
    y_train = y[: split]
    y_test = y[split:]
    return(X_train, X_test, y_train, y_test)


evaluations = []
for n in range(1,11):
    X, y = window_data(df, n, feature_column, target_column)
    X_train, X_test, y_train, y_test = split(X, y)
    x_train_scaler = MinMaxScaler()
    x_test_scaler = MinMaxScaler()
    y_train_scaler = MinMaxScaler()
    y_test_scaler = MinMaxScaler()


    #fit da scalers to training data
    x_train_scaler.fit(X_train)
    y_train_scaler.fit(y_train)

    #fit da training scaler
    X_train = x_train_scaler.transform(X_train)
    y_train = y_train_scaler.transform(y_train)

    #fit da scalers to test data
    x_test_scaler.fit(X_test)
    y_test_scaler.fit(y_test)

    #fit da test scalers
    X_test = x_test_scaler.transform(X_test)
    y_test = y_test_scaler.transform(y_test)
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
    model = Sequential()

    number_units = 30
    dropout_fraction = 0.1


    # Layer 1
    model.add(LSTM(
        units=number_units,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1))
        )
    model.add(Dropout(dropout_fraction))
    # Layer 2
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    # Layer 3
    model.add(LSTM(units=number_units))
    model.add(Dropout(dropout_fraction))
    # Output layer
    model.add(Dense(1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    model.summary()
    model.fit(X_train, y_train, epochs=20, shuffle=False, batch_size=1, verbose=1)
    
    evaluations.append(model.evaluate(X_test, y_test))
    predicted = model.predict(X_test)
    predicted_prices = y_test_scaler.inverse_transform(predicted)
    real_prices = y_test_scaler.inverse_transform(y_test.reshape(-1, 1))
    stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = df.index[-len(real_prices): ]) 
    stocks.head()
    stocks.plot()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_33 (LSTM)               (None, 1, 30)             3840
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 1, 30)             0
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 1, 30)             7320
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 1, 30)             0
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 378/378 [==============================] - 4s 2ms/step - loss: 0.1903
# Epoch 2/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1076
# Epoch 3/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1055
# Epoch 4/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0996
# Epoch 5/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0998
# Epoch 6/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0984
# Epoch 7/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0960
# Epoch 8/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0974
# Epoch 9/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0966
# Epoch 10/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0962
# Epoch 11/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0988
# Epoch 12/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1034
# Epoch 13/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1034
# Epoch 14/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1008
# Epoch 15/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0999
# Epoch 16/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0999
# Epoch 17/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1003
# Epoch 18/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1013
# Epoch 19/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0993
# Epoch 20/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1003
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1040
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_36 (LSTM)               (None, 2, 30)             3840
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 2, 30)             0
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 2, 30)             7320
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 2, 30)             0
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 378/378 [==============================] - 4s 3ms/step - loss: 0.1507
# Epoch 2/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0963
# Epoch 3/20
# 378/378 [==============================] - 1s 3ms/step - loss: 0.1021
# Epoch 4/20
# 378/378 [==============================] - 1s 3ms/step - loss: 0.1000
# Epoch 5/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0989
# Epoch 6/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0986
# Epoch 7/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0976
# Epoch 8/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0998
# Epoch 9/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1002
# Epoch 10/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1008
# Epoch 11/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1006
# Epoch 12/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1010
# Epoch 13/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1020
# Epoch 14/20
# 378/378 [==============================] - 1s 3ms/step - loss: 0.1010
# Epoch 15/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1038
# Epoch 16/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1022
# Epoch 17/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.0990
# Epoch 18/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1025
# Epoch 19/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1048
# Epoch 20/20
# 378/378 [==============================] - 1s 2ms/step - loss: 0.1039
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1006
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_39 (LSTM)               (None, 3, 30)             3840
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 3, 30)             0
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 3, 30)             7320
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 3, 30)             0
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 377/377 [==============================] - 4s 3ms/step - loss: 0.1244
# Epoch 2/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0891
# Epoch 3/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1022
# Epoch 4/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1002
# Epoch 5/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0972
# Epoch 6/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0936
# Epoch 7/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0915
# Epoch 8/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0949
# Epoch 9/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1000
# Epoch 10/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1016
# Epoch 11/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1015
# Epoch 12/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1050
# Epoch 13/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1058
# Epoch 14/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1053
# Epoch 15/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1022
# Epoch 16/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1024
# Epoch 17/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1045
# Epoch 18/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1039
# Epoch 19/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1028A: 0s - loss:
# Epoch 20/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.1038
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1029
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_42 (LSTM)               (None, 4, 30)             3840
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 4, 30)             0
# _________________________________________________________________
# lstm_43 (LSTM)               (None, 4, 30)             7320
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 4, 30)             0
# _________________________________________________________________
# lstm_44 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 376/376 [==============================] - 5s 4ms/step - loss: 0.1105
# Epoch 2/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0870
# Epoch 3/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1017
# Epoch 4/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0973
# Epoch 5/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0954
# Epoch 6/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0926
# Epoch 7/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0873
# Epoch 8/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0879
# Epoch 9/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0950
# Epoch 10/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0946
# Epoch 11/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0994
# Epoch 12/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1036
# Epoch 13/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1077
# Epoch 14/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1046
# Epoch 15/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1063
# Epoch 16/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1063
# Epoch 17/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1038
# Epoch 18/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1063
# Epoch 19/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1048
# Epoch 20/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.1070
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1041
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_45 (LSTM)               (None, 5, 30)             3840
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 5, 30)             0
# _________________________________________________________________
# lstm_46 (LSTM)               (None, 5, 30)             7320
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 5, 30)             0
# _________________________________________________________________
# lstm_47 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 4s 4ms/step - loss: 0.0827
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0780
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0923A: 0s - loss: 0.093
# Epoch 4/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0996
# Epoch 5/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0980
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0923
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0920
# Epoch 8/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0915
# Epoch 9/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0966
# Epoch 10/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0994
# Epoch 11/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1016
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1053
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1127
# Epoch 14/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1113
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1092
# Epoch 16/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1107
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1081
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1095
# Epoch 19/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1083
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1070
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1032
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_48 (LSTM)               (None, 6, 30)             3840
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 6, 30)             0
# _________________________________________________________________
# lstm_49 (LSTM)               (None, 6, 30)             7320
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 6, 30)             0
# _________________________________________________________________
# lstm_50 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 5s 4ms/step - loss: 0.0970
# Epoch 2/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0906
# Epoch 3/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1058
# Epoch 4/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1092
# Epoch 5/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1016
# Epoch 6/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1069
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1062
# Epoch 8/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0958
# Epoch 9/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0997
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0930
# Epoch 11/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0939
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0992
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1140
# Epoch 14/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1094
# Epoch 15/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1185
# Epoch 16/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1119
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1101
# Epoch 18/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1122
# Epoch 19/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1139
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1134
# 6/6 [==============================] - 1s 2ms/step - loss: 0.1354
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_51 (LSTM)               (None, 7, 30)             3840
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 7, 30)             0
# _________________________________________________________________
# lstm_52 (LSTM)               (None, 7, 30)             7320
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 7, 30)             0
# _________________________________________________________________
# lstm_53 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 374/374 [==============================] - 5s 4ms/step - loss: 0.0955
# Epoch 2/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0887
# Epoch 3/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1087
# Epoch 4/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1092
# Epoch 5/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1069
# Epoch 6/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1065
# Epoch 7/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1037
# Epoch 8/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0979
# Epoch 9/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0969
# Epoch 10/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1050
# Epoch 11/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1098
# Epoch 12/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1269
# Epoch 13/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1336
# Epoch 14/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1201
# Epoch 15/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1167
# Epoch 16/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1177
# Epoch 17/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1159
# Epoch 18/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1147
# Epoch 19/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1157
# Epoch 20/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.1181
# 6/6 [==============================] - 1s 3ms/step - loss: 0.1056
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_54 (LSTM)               (None, 8, 30)             3840
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 8, 30)             0
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 8, 30)             7320
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 8, 30)             0
# _________________________________________________________________
# lstm_56 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 373/373 [==============================] - 5s 5ms/step - loss: 0.1053
# Epoch 2/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1026
# Epoch 3/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1077
# Epoch 4/20
# 373/373 [==============================] - 2s 6ms/step - loss: 0.1094
# Epoch 5/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1100
# Epoch 6/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1058
# Epoch 7/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0911
# Epoch 8/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0923
# Epoch 9/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0953
# Epoch 10/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1029
# Epoch 11/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1168
# Epoch 12/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1074
# Epoch 13/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1198
# Epoch 14/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1273
# Epoch 15/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0804
# Epoch 16/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1231
# Epoch 17/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1396
# Epoch 18/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1271
# Epoch 19/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1264
# Epoch 20/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0673
# 6/6 [==============================] - 1s 3ms/step - loss: 0.1907
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_57 (LSTM)               (None, 9, 30)             3840
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 9, 30)             0
# _________________________________________________________________
# lstm_58 (LSTM)               (None, 9, 30)             7320
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 9, 30)             0
# _________________________________________________________________
# lstm_59 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 373/373 [==============================] - 5s 5ms/step - loss: 0.1003
# Epoch 2/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0991
# Epoch 3/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1062
# Epoch 4/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1107
# Epoch 5/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1068
# Epoch 6/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1094
# Epoch 7/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1038
# Epoch 8/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0957
# Epoch 9/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0953
# Epoch 10/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1016
# Epoch 11/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1311
# Epoch 12/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1329
# Epoch 13/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1210
# Epoch 14/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1351
# Epoch 15/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1410
# Epoch 16/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1258
# Epoch 17/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1210
# Epoch 18/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.1210
# Epoch 19/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0913
# Epoch 20/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0977
# 5/5 [==============================] - 1s 3ms/step - loss: 0.1738
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_60 (LSTM)               (None, 10, 30)            3840
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 10, 30)            0
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 10, 30)            7320
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 10, 30)            0
# _________________________________________________________________
# lstm_62 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 372/372 [==============================] - 5s 5ms/step - loss: 0.0980
# Epoch 2/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1035
# Epoch 3/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1119
# Epoch 4/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1094
# Epoch 5/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1042
# Epoch 6/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1110
# Epoch 7/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0981
# Epoch 8/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1035
# Epoch 9/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0984
# Epoch 10/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1219
# Epoch 11/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1254
# Epoch 12/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1595
# Epoch 13/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1471
# Epoch 14/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1304
# Epoch 15/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1453
# Epoch 16/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1266
# Epoch 17/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1219
# Epoch 18/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1211
# Epoch 19/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1180
# Epoch 20/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.1137
# 5/5 [==============================] - 1s 3ms/step - loss: 0.0957

# %%
evaluations
# Out:
# [0.10401975363492966,
#  0.10060211271047592,
#  0.10289249569177628,
#  0.10408632457256317,
#  0.10323451459407806,
#  0.13537313044071198,
#  0.10559804737567902,
#  0.19074584543704987,
#  0.1738351285457611,
#  0.09568674862384796]
